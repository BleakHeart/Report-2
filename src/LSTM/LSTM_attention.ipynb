# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datetime import timedelta
import sys
sys.path.append('../../lib/')
from analysis import *
import pickle as pkl

# %%
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import LSTM, Dense, RepeatVector, TimeDistributed, \
    Input, BatchNormalization, multiply, concatenate, Flatten, Activation, dot
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping

import pydot as pyd
from tensorflow.keras.utils import plot_model, model_to_dot
import tensorflow
tensorflow.keras.utils.pydot = pyd

# %% [markdown]
# Read Data

# %%
data = pkl.load(open('../../Data/data.pkl', 'rb'))

X_input_train = data['X_input_train']
X_output_train = data['X_output_train']
X_input_test = data['X_input_test']
X_output_test = data['X_output_test']

x_trend_param = data['x_trend_param']
x_train_max = data['x_train_max']

# %% [markdown]
# Model

# %%
n_hidden = 100
input_train = Input(shape=(X_input_train.shape[1], X_input_train.shape[2]-1))
output_train = Input(shape=(X_output_train.shape[1], X_output_train.shape[2]-1))


encoder_stack_h, encoder_last_h, encoder_last_c = LSTM(
    n_hidden, activation='elu', dropout=0.2, recurrent_dropout=0.2, 
    return_state=True, return_sequences=True)(input_train)

# %%
encoder_last_h = BatchNormalization(momentum=0.6)(encoder_last_h) 
encoder_last_c = BatchNormalization(momentum=0.6)(encoder_last_c) 
decoder_input = RepeatVector(output_train.shape[1])(encoder_last_h)
decoder_stack_h = LSTM(n_hidden, activation='elu', dropout=0.2,
                       recurrent_dropout=0.2, return_state=False, 
                       return_sequences=True)(decoder_input,
                                              initial_state=[encoder_last_h,
                                                             encoder_last_c])
                       
attention = dot([decoder_stack_h, encoder_stack_h], axes=[2, 2])
attention = Activation('softmax')(attention)

# %%
context = dot([attention, encoder_stack_h], axes=[2,1])
context = BatchNormalization(momentum=0.6)(context)
decoder_combined_context = concatenate([context, decoder_stack_h])
out = TimeDistributed(Dense(output_train.shape[2]))(decoder_combined_context)

# %%
model = Model(inputs=input_train, outputs=out)
opt = Adam(lr=0.01, clipnorm=1)
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mae'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 200, 1)]     0           []
#
#  lstm (LSTM)                    [(None, 200, 100),   40800       ['input_1[0][0]']
#                                  (None, 100),
#                                  (None, 100)]
#
#  batch_normalization (BatchNorm  (None, 100)         400         ['lstm[0][1]']
#  alization)
#
#  repeat_vector (RepeatVector)   (None, 20, 100)      0           ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 100)         400         ['lstm[0][2]']
#  rmalization)
#
#  lstm_1 (LSTM)                  (None, 20, 100)      80400       ['repeat_vector[0][0]',
#                                                                   'batch_normalization[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  dot (Dot)                      (None, 20, 200)      0           ['lstm_1[0][0]',
#                                                                   'lstm[0][0]']
#
#  activation (Activation)        (None, 20, 200)      0           ['dot[0][0]']
#
#  dot_1 (Dot)                    (None, 20, 100)      0           ['activation[0][0]',
#                                                                   'lstm[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 20, 100)     400         ['dot_1[0][0]']
#  rmalization)
#
#  concatenate (Concatenate)      (None, 20, 200)      0           ['batch_normalization_2[0][0]',
#                                                                   'lstm_1[0][0]']
#
#  time_distributed (TimeDistribu  (None, 20, 1)       201         ['concatenate[0][0]']
#  ted)
#
# ==================================================================================================
# Total params: 122,601
# Trainable params: 122,001
# Non-trainable params: 600
# __________________________________________________________________________________________________
# C:\Users\manue\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
epc = 100
es = EarlyStopping(monitor='val_loss', mode='min', patience=50)
history = model.fit(X_input_train[:, :, :1], X_output_train[:, :, :1],
                    validation_split=0.2, 
                    epochs=epc, verbose=1, callbacks=[es], 
                    batch_size=300)
train_mae = history.history['mae']
valid_mae = history.history['val_mae']

model.save('model_forecasting_seq2seq_attention.h5')
# Out:
# Epoch 1/100
# 2/2 [==============================] - 7s 1s/step - loss: 7.3558 - mae: 1.9554 - val_loss: 0.1491 - val_mae: 0.3475
# Epoch 2/100
# 2/2 [==============================] - 2s 744ms/step - loss: 5.6828 - mae: 1.6469 - val_loss: 0.1977 - val_mae: 0.3840
# Epoch 3/100
# 2/2 [==============================] - 2s 765ms/step - loss: 2.9919 - mae: 1.0328 - val_loss: 0.2298 - val_mae: 0.3626
# Epoch 4/100
# 2/2 [==============================] - 2s 768ms/step - loss: 1.2569 - mae: 0.8412 - val_loss: 0.2772 - val_mae: 0.4707
# Epoch 5/100
# 2/2 [==============================] - 2s 759ms/step - loss: 0.2601 - mae: 0.3952 - val_loss: 0.3017 - val_mae: 0.4684
# Epoch 6/100
# 2/2 [==============================] - 2s 943ms/step - loss: 0.2017 - mae: 0.3506 - val_loss: 0.2028 - val_mae: 0.3794
# Epoch 7/100
# 2/2 [==============================] - 2s 887ms/step - loss: 0.1412 - mae: 0.2894 - val_loss: 0.2981 - val_mae: 0.4633
# Epoch 8/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.1024 - mae: 0.2566 - val_loss: 0.1808 - val_mae: 0.3627
# Epoch 9/100
# 2/2 [==============================] - 2s 958ms/step - loss: 0.1031 - mae: 0.2399 - val_loss: 0.2557 - val_mae: 0.4278
# Epoch 10/100
# 2/2 [==============================] - 2s 894ms/step - loss: 0.0981 - mae: 0.2448 - val_loss: 0.1900 - val_mae: 0.3664
# Epoch 11/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0910 - mae: 0.2317 - val_loss: 0.1554 - val_mae: 0.3297
# Epoch 12/100
# 2/2 [==============================] - 2s 952ms/step - loss: 0.0887 - mae: 0.2239 - val_loss: 0.1894 - val_mae: 0.3699
# Epoch 13/100
# 2/2 [==============================] - 2s 975ms/step - loss: 0.0861 - mae: 0.2224 - val_loss: 0.1774 - val_mae: 0.3539
# Epoch 14/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0766 - mae: 0.2086 - val_loss: 0.1542 - val_mae: 0.3241
# Epoch 15/100
# 2/2 [==============================] - 2s 978ms/step - loss: 0.0731 - mae: 0.2008 - val_loss: 0.1595 - val_mae: 0.3295
# Epoch 16/100
# 2/2 [==============================] - 2s 973ms/step - loss: 0.0775 - mae: 0.2104 - val_loss: 0.2436 - val_mae: 0.4199
# Epoch 17/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0743 - mae: 0.2081 - val_loss: 0.1446 - val_mae: 0.3167
# Epoch 18/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0717 - mae: 0.2033 - val_loss: 0.1453 - val_mae: 0.3150
# Epoch 19/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0761 - mae: 0.2031 - val_loss: 0.2044 - val_mae: 0.3879
# Epoch 20/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0704 - mae: 0.2011 - val_loss: 0.3597 - val_mae: 0.5331
# Epoch 21/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0856 - mae: 0.2260 - val_loss: 0.2447 - val_mae: 0.4153
# Epoch 22/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0674 - mae: 0.1978 - val_loss: 0.1297 - val_mae: 0.2917
# Epoch 23/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0785 - mae: 0.2104 - val_loss: 0.1406 - val_mae: 0.3036
# Epoch 24/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0747 - mae: 0.2120 - val_loss: 0.0823 - val_mae: 0.2373
# Epoch 25/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0734 - mae: 0.2054 - val_loss: 0.1273 - val_mae: 0.2725
# Epoch 26/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0699 - mae: 0.2002 - val_loss: 0.0703 - val_mae: 0.2073
# Epoch 27/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0711 - mae: 0.2013 - val_loss: 0.1467 - val_mae: 0.3101
# Epoch 28/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0705 - mae: 0.2029 - val_loss: 0.1371 - val_mae: 0.2896
# Epoch 29/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0681 - mae: 0.1983 - val_loss: 0.1492 - val_mae: 0.3171
# Epoch 30/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0673 - mae: 0.2018 - val_loss: 0.1131 - val_mae: 0.2616
# Epoch 31/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0640 - mae: 0.1918 - val_loss: 0.1061 - val_mae: 0.2528
# Epoch 32/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0565 - mae: 0.1802 - val_loss: 0.1319 - val_mae: 0.3017
# Epoch 33/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0557 - mae: 0.1773 - val_loss: 0.1328 - val_mae: 0.2985
# Epoch 34/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0580 - mae: 0.1806 - val_loss: 0.1555 - val_mae: 0.3286
# Epoch 35/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0559 - mae: 0.1781 - val_loss: 0.1604 - val_mae: 0.3195
# Epoch 36/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0573 - mae: 0.1818 - val_loss: 0.1658 - val_mae: 0.3142
# Epoch 37/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0574 - mae: 0.1824 - val_loss: 0.1166 - val_mae: 0.2715
# Epoch 38/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0591 - mae: 0.1862 - val_loss: 0.1625 - val_mae: 0.3293
# Epoch 39/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0611 - mae: 0.1932 - val_loss: 0.1371 - val_mae: 0.2899
# Epoch 40/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0580 - mae: 0.1858 - val_loss: 0.1422 - val_mae: 0.2984
# Epoch 41/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0564 - mae: 0.1834 - val_loss: 0.1195 - val_mae: 0.2636
# Epoch 42/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0583 - mae: 0.1814 - val_loss: 0.0995 - val_mae: 0.2507
# Epoch 43/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0500 - mae: 0.1710 - val_loss: 0.0998 - val_mae: 0.2484
# Epoch 44/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0490 - mae: 0.1709 - val_loss: 0.1352 - val_mae: 0.2964
# Epoch 45/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0496 - mae: 0.1714 - val_loss: 0.1043 - val_mae: 0.2586
# Epoch 46/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0454 - mae: 0.1636 - val_loss: 0.0983 - val_mae: 0.2541
# Epoch 47/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0461 - mae: 0.1641 - val_loss: 0.0833 - val_mae: 0.2345
# Epoch 48/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.1731 - mae: 0.2568 - val_loss: nan - val_mae: nan
# Epoch 49/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.4365 - mae: 0.4790 - val_loss: nan - val_mae: nan
# Epoch 50/100
# 2/2 [==============================] - 3s 1s/step - loss: 1.1338 - mae: 0.5784 - val_loss: nan - val_mae: nan
# Epoch 51/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.9722 - mae: 0.5990 - val_loss: nan - val_mae: nan
# Epoch 52/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.5988 - mae: 0.5306 - val_loss: nan - val_mae: nan
# Epoch 53/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.6056 - mae: 0.5417 - val_loss: nan - val_mae: nan
# Epoch 54/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.5694 - mae: 0.5220 - val_loss: nan - val_mae: nan
# Epoch 55/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.5284 - mae: 0.5079 - val_loss: nan - val_mae: nan
# Epoch 56/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.4477 - mae: 0.4861 - val_loss: nan - val_mae: nan
# Epoch 57/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.4235 - mae: 0.4837 - val_loss: nan - val_mae: nan
# Epoch 58/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3884 - mae: 0.4727 - val_loss: nan - val_mae: nan
# Epoch 59/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3894 - mae: 0.4784 - val_loss: nan - val_mae: nan
# Epoch 60/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3378 - mae: 0.4571 - val_loss: nan - val_mae: nan
# Epoch 61/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3580 - mae: 0.4654 - val_loss: nan - val_mae: nan
# Epoch 62/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.2817 - mae: 0.4454 - val_loss: nan - val_mae: nan
# Epoch 63/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.2883 - mae: 0.4513 - val_loss: nan - val_mae: nan
# Epoch 64/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3820 - mae: 0.4826 - val_loss: nan - val_mae: nan
# Epoch 65/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3626 - mae: 0.4678 - val_loss: nan - val_mae: nan
# Epoch 66/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3383 - mae: 0.4657 - val_loss: nan - val_mae: nan
# Epoch 67/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3381 - mae: 0.4682 - val_loss: nan - val_mae: nan
# Epoch 68/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3314 - mae: 0.4708 - val_loss: nan - val_mae: nan
# Epoch 69/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3404 - mae: 0.4592 - val_loss: nan - val_mae: nan
# Epoch 70/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3004 - mae: 0.4508 - val_loss: nan - val_mae: nan
# Epoch 71/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.2892 - mae: 0.4469 - val_loss: nan - val_mae: nan
# Epoch 72/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3053 - mae: 0.4424 - val_loss: nan - val_mae: nan
# Epoch 73/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3123 - mae: 0.4626 - val_loss: nan - val_mae: nan
# Epoch 74/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3107 - mae: 0.4513 - val_loss: nan - val_mae: nan
# Epoch 75/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3229 - mae: 0.4595 - val_loss: nan - val_mae: nan
# Epoch 76/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3094 - mae: 0.4484 - val_loss: nan - val_mae: nan

# %%
plt.plot(train_mae, label='train mae'), 
plt.plot(valid_mae, label='validation mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.title('train vs. validation accuracy (mae)')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)
plt.show()

# %% [markdown]
# Predict

# %%
def LSTM_model_prediction(model, X_input_train, X_input_test, x_train_max,
                          X_output_train, X_output_test):
    
    train_pred_detrend = model.predict(X_input_train[:, :, :1])*x_train_max[:2]
    test_pred_detrend = model.predict(X_input_test[:, :, :1])*x_train_max[:2]

    train_true_detrend = X_output_train[:, :, :1]*x_train_max[:2]
    test_true_detrend = X_output_test[:, :, :1]*x_train_max[:2]
    
    # combine with the index
    train_pred_detrend = np.concatenate([train_pred_detrend,
                                         np.expand_dims(X_output_train[:, :, 1],
                                                        axis=2)], axis=2)
    test_pred_detrend = np.concatenate([test_pred_detrend,
                                        np.expand_dims(X_output_test[:, :, 1],
                                                       axis=2)], axis=2)

    train_true_detrend = np.concatenate([train_true_detrend,
                                         np.expand_dims(X_output_train[:, :, 1],
                                                        axis=2)], axis=2)
    test_true_detrend = np.concatenate([test_true_detrend,
                                        np.expand_dims(X_output_test[:, :, 1],
                                                       axis=2)], axis=2)
    # recover trend
    data_final = dict()

    for dt, lb in zip([train_pred_detrend, train_true_detrend, test_pred_detrend, test_true_detrend], 
                    ['train_pred', 'train_true', 'test_pred', 'test_true']):
        dt_x = dt[:, :, 0] + dt[:, :, 1] * x_trend_param[0] + x_trend_param[1]
        data_final[lb] = np.expand_dims(dt_x, axis=2)    
    
    return data_final


data_final = LSTM_model_prediction(model, X_input_train, X_input_test, x_train_max,
                                   X_output_train, X_output_test)

# %%
for k in ['train_pred', 'train_true', 'test_pred', 'test_true']:
    print('maximum: {}'.format(k))
    print(data_final[k].max())
# Out:
# maximum: train_pred
# nan
# maximum: train_true
# 25285.37453592877
# maximum: test_pred
# nan
# maximum: test_true
# 24948.27873213366

# %%
for lb in ['train', 'test']:
    plt.figure(figsize=(15, 4))
    plt.hist(data_final[lb+'_pred'].flatten(), bins=100, color='orange', alpha=0.5, label=lb+' pred')
    plt.hist(data_final[lb+'_true'].flatten(), bins=100, color='green', alpha=0.5, label=lb+' true')
    plt.legend()
    plt.title('value distribution: '+lb)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-f2d86c62a15c> in <module>
#       1 for lb in ['train', 'test']:
#       2     plt.figure(figsize=(15, 4))
# ----> 3     plt.hist(data_final[lb+'_pred'].flatten(), bins=100, color='orange', alpha=0.5, label=lb+' pred')
#       4     plt.hist(data_final[lb+'_true'].flatten(), bins=100, color='green', alpha=0.5, label=lb+' true')
#       5     plt.legend()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2851         orientation='vertical', rwidth=None, log=False, color=None,
#    2852         label=None, stacked=False, *, data=None, **kwargs):
# -> 2853     return gca().hist(
#    2854         x, bins=bins, range=range, density=density, weights=weights,
#    2855         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6757             # this will automatically overwrite bins,
#    6758             # so that each histogram uses the same bins
# -> 6759             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6760             tops.append(m)
#    6761         tops = np.array(tops, float)  # causes problems later if it's an int
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\histograms.py in histogram(a, bins, range, normed, weights, density)
#     790     a, weights = _ravel_and_check_weights(a, weights)
#     791
# --> 792     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     793
#     794     # Histogram is an integer or a float array depending on the weights.
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\histograms.py in _get_bin_edges(a, bins, range, weights)
#     424             raise ValueError('`bins` must be positive, when an integer')
#     425
# --> 426         first_edge, last_edge = _get_outer_edges(a, range)
#     427
#     428     elif np.ndim(bins) == 1:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\histograms.py in _get_outer_edges(a, range)
#     321         first_edge, last_edge = a.min(), a.max()
#     322         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# --> 323             raise ValueError(
#     324                 "autodetected range of [{}, {}] is not finite".format(first_edge, last_edge))
#     325
#
# ValueError: autodetected range of [nan, nan] is not finite

# %%
for lb in ['train', 'test']:
    MAE_overall = abs(data_final[lb+'_pred'] - data_final[lb+'_true']).mean()
    MAE_ = abs(data_final[lb+'_pred'] - data_final[lb+'_true']).mean(axis=(1, 2))
    plt.figure(figsize=(15, 3))
    plt.plot(MAE_)
    plt.title('MAE '+lb+': overall MAE = '+str(MAE_overall))
    plt.show()

# %%
import random

for lb in ['train', 'test']:
    ith_sample = random.choice(range(data_final[lb+'_pred'].shape[0]))

    plt.figure(figsize=(15,3))
    plt.plot(data_final[lb+'_pred'][ith_sample, :, 0], linestyle='--', color='r', label='pred x')
    plt.plot(data_final[lb+'_true'][ith_sample, :, 0], linestyle='-', color='b', label='true x')
    plt.title('({}): {}th sample'.format(lb, ith_sample))
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)
    plt.show()

# %%
timestep = random.choice(range(data_final[lb+'_pred'].shape[1]))
for lb in ['train', 'test']:   
    plt.figure(figsize=(15, 5))
    plt.plot(data_final[lb+'_pred'][:, timestep, 0], linestyle='--', color='r', label='pred x')
    plt.plot(data_final[lb+'_true'][:, timestep, 0], linestyle='-', color='b', label='true x')
    plt.title('({}): {}th time step in all samples'.format(lb, timestep))
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)
    plt.show()

# %%
plt.figure(figsize=(15, 5))
train_start_t = 0
test_start_t = data_final['train_pred'].shape[0]


labels = ['train', 'test']
variables = [train_start_t, test_start_t]
colors = [['green', 'red'], ['blue', 'orange']]

for lb, tm, clrs in zip(labels, variables, colors):
    n = data_final[f'{lb}_pred'].shape[0]
    plt.plot(range(tm, tm + n), 
             data_final[f'{lb}_pred'][:, timestep, 0], 
             linestyle='--', linewidth=1, color=clrs[0], label=f'{lb} pred')
    plt.plot(range(tm, tm + n), 
             data_final[f'{lb}_true'][:, timestep, 0], 
             linestyle='-', linewidth=1, color=clrs[1], label=f'{lb} true')
    
plt.title(f'{timestep}th time step in all samples')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
           fancybox=True, shadow=False, ncol=8)
plt.show()
